# %% [markdown]
# # Acoustic Feature Extraction from African Elephant Rumbles
# This is a rewrite of of the `Arden_acousticAnalysis.ipynb` file using a custom python module.

# %%
import ardenanalysis
from pathlib import Path
import os

# %%
annotation_dir = Path(os.getenv('ANNOTATION_PATH'))
audio_dir = Path(os.getenv('AUDIO_PATH'))
fig_dir = Path(os.getenv('FIG_PATH'))

arden_data_driver = ardenanalysis.DataDriver(annotation_dir, audio_dir, fig_dir)

# %%
results = arden_data_driver.process()
results.head()
# Out:
#                 filename           rec_start                  abs_begin  \
# 0  Arden_20250606_130050 2025-06-06 13:00:50 2025-06-06 13:08:44.246619
# 1  Arden_20250606_130050 2025-06-06 13:00:50 2025-06-06 13:10:29.161466
# 2  Arden_20250606_140055 2025-06-06 14:00:55 2025-06-06 14:12:16.560669
# 3  Arden_20250606_140055 2025-06-06 14:00:55 2025-06-06 14:14:18.574893
# 4  Arden_20250606_140055 2025-06-06 14:00:55 2025-06-06 14:16:52.798276
#
#                      abs_end  duration  Selection           View  Channel  \
# 0 2025-06-06 13:08:49.858403  5.611785          5  Spectrogram 1        1
# 1 2025-06-06 13:10:36.030277  6.868811         10  Spectrogram 1        1
# 2 2025-06-06 14:12:20.784060  4.223391          3  Spectrogram 1        1
# 3 2025-06-06 14:14:23.958556  5.383663          4  Spectrogram 1        1
# 4 2025-06-06 14:16:58.506815  5.708539          9  Spectrogram 1        1
#
#    Begin Time (s)  End Time (s)  ...  mel_mean_17  mel_mean_18 mel_mean_19  \
# ...

# %%
arden_data_driver.save_images()
