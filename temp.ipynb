# %%
import os
import pandas as pd
from a3em.datasets import arden
from pathlib import Path

path = Path(os.getenv('DATA_PATH'))

# %%
x_train, y_train, x_label, y_label = arden.load_data(path, test_split=0.2, random_state=123)
x_train.head()

# %%
rows = []
for _, row in arden.iterclip(path):
    rows.append(row)
df = pd.DataFrame(rows)
df.head()
