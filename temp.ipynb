# %%
import os
from a3em.datasets import arden
from pathlib import Path

path = Path(os.getenv('DATA_PATH'))
(x_train, y_train), (x_test, y_test) = arden.load_data(path, test_split=0.2, random_state=123)
x_train.head()
# Out:
# loading audio data
# checking for existing files
# prefetch complete
# extracting rumbles
# extraction complete
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       3 from pathlib import Path
#       5 path = Path(os.getenv('DATA_PATH'))
# ----> 6 (x_train, y_train), (x_test, y_test) = arden.load_data(path, test_split=0.2, random_state=123)
#       7 x_train.head()
#
# ValueError: too many values to unpack (expected 2)
